# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("tmdb_movies_data.csv")

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df['profit'] = df['revenue'] - df['budget']

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
plt.scatter('budget','profit')

# %%
df['budget'].describe()
# Out:
# count    1.086600e+04
# mean     1.462570e+07
# std      3.091321e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.500000e+07
# max      4.250000e+08
# Name: budget, dtype: float64

# %%
df = df[df['budget'] > 0]

# %%
plt.scatter('budget','profit')

# %%
df['profit'].describe()
# Out:
# count    5.170000e+03
# mean     4.953623e+07
# std      1.351241e+08
# min     -4.139124e+08
# 25%     -6.599420e+06
# 50%      2.503684e+06
# 75%      5.278727e+07
# max      2.544506e+09
# Name: profit, dtype: float64

# %%
plt.scatter(df['budget']/1000000, df['profit']/1000000)

# %%
plt.scatter(df['budget']/1000000, df['profit']/1000000)
plt.xlabel('Budget (millions)')
plt.ylabel('Profit (millions)')
plt.title('Budget vs Profit')
plt.show()

# %%
df['ROI']=df['profit']/df['budget']

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.groupby('genres')['ROI'].mean()
# Out:
# genres
# Action                                                0.190834
# Action|Adventure                                      1.320670
# Action|Adventure|Animation|Family|Fantasy             3.269134
# Action|Adventure|Animation|Family|Science Fiction     5.863501
# Action|Adventure|Animation|Fantasy|Science Fiction   -1.000000
#                                                         ...
# Western|Drama|Comedy|Romance                         -1.000000
# Western|History                                       0.579519
# Western|History|War                                  -0.821931
# Western|Horror|Thriller                              -1.000000
# Western|Thriller                                     -0.999122
# Name: ROI, Length: 1288, dtype: float64

# %%
roi_by_genre=df.groupby('genres')['ROI'].mean()

# %%
plt.bar(roi_top10.index, roi_top10.values)
plt.xticks(rotation=90)
roi_top10 = roi_by_genre.sort_values(ascending=False).head(10)
plt.show()

# %%
roi_top10 = roi_by_genre.sort_values(ascending=False).iloc[1:11]
plt.bar(roi_top10.index, roi_top10.values)
plt.xticks(rotation=90)
plt.xlabel('genre')
plt.ylabel('AVG ROI')
plt.title('genres vs ROI')
plt.show()
